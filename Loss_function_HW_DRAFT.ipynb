# %% [markdown]
# #### Домашнее задание (Функции потерь)
#
# Реализовать самостоятельно логистическую регрессию
#
# Обучить ее методом градиентного спуска
#
# Методом nesterov momentum
#
# Методом rmsprop
#
# В качестве dataset'а взять Iris, оставив 2 класса:
# Iris Versicolor
# Iris Virginica

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %config InlineBackend.figure_format = 'svg' 
# %matplotlib inline


from jupyterthemes import jtplot
jtplot.style(figsize=(9.0, 6.0))

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Реализация
#
# Алгоритм:
#
# - напишем решающую функцию (логистическая регрессия)
# - напишем функцию градиентного спуска
# - обучим нашу логистическую регрессию (различными методами: )

# %% [markdown]
# 1.1. Загрузим набор данных

# %%
iris = load_iris()

# %% [markdown]
# - Сначала посмотрим на распределение всех обьектов из нашего набора данных

# %%
X1 = iris.data[:, :]
y1 = iris.target

# %%
plt.scatter(X1[y1 == 0][:, 0], X1[y1 == 0][:, 2], color='g', label='setosa')
plt.scatter(X1[y1 == 1][:, 0], X1[y1 == 1][:, 2], color='r', label='versicolor')
plt.scatter(X1[y1 == 2][:, 0], X1[y1 == 2][:, 2], color='b', label='virginica')

plt.legend();

# %%
plt.scatter(X1[y1 == 1][:, 0], X1[y1 == 1][:, 2], color='r', label='versicolor')
plt.scatter(X1[y1 == 2][:, 0], X1[y1 == 2][:, 2], color='b', label='virginica')

plt.legend();

# %% [markdown]
# - В качестве dataset'а взять Iris, оставив 2 класса: Iris Versicolor Iris Virginica

# %%
X = iris.data[:, :2]
y = (iris.target != 0)*1
